# %%
# Install pandas
# !pip install pandas
# Import Pandas Data frame and read_csv
from pandas import DataFrame, read_csv
import pandas as pd 
# Import Matplotlib
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# Load data of normal distribution (coarse size) - step #0
normal_coarse = r'./normal-coarse.csv'
df = pd.read_csv(normal_coarse,delimiter='|')
df
# Out:
#                                     analysis  timestep     eid     stiffness  \
# 0       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       0  5.282624e+04
# 1       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       1  3.616878e+04
# 2       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       2  1.000000e-20
# 3       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       3  2.560950e+04
# 4       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       4  3.997355e+04
# 5       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       5  8.581818e+04
# 6       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       6  6.574248e+04
# 7       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       7  1.000000e-20
# 8       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       8  9.188773e+03
# 9       26a6eff4-d99f-4b68-aa69-c127521d0eb5         0       9  1.339663e+04
# 10      26a6eff4-d99f-4b68-aa69-c127521d0eb5         0      10  2.639126e+04
# ...

# %%
# Plot Emicro distribution
# %matplotlib inline

# %%
df.emicro.plot.hist(alpha=0.5, bins=100)

# %%
# Minimum Emicro
df.emicro.min()
# Out:
# 37378.596540063802

# %%
# Maximum Emicro
df.emicro.max()
# Out:
# 101212.48753170599

# %%
# Average Emicro 
df.emicro.sum() / df.emicro.count()
# Out:
# 71420.000000000509

# %%
# Plot stiffness distribution
df.stiffness.plot.hist(alpha=0.5, bins=100)

# %%
# Minimum stiffness
df.stiffness.min()
# Out:
# 1.0000000000000001e-20

# %%
# Maximum stiffness
df.stiffness.max()
# Out:
# 409852.26294133102

# %%
# Average stiffness
df.stiffness.sum() / df.stiffness.count()
# Out:
# 32302.517067646717

# %%
# Plot tensile_strength distribution
df.tensile_strength.plot.hist(alpha=0.5, bins=100)

# %%
# Minimum tensile_strenght
df.tensile_strength.min()
# Out:
# 10.2212824198746

# %%
# Maximum tensile_strenght
df.tensile_strength.max()
# Out:
# 27.676839561666498

# %%
# Average tensile_strenght
df.tensile_strength.sum() / df.tensile_strength.count()
# Out:
# 19.530000000000129

# %%
# Plot Length distribution
df.length.plot.hist(alpha=0.5, bins=100)
